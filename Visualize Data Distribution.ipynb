# %%
from matplotlib import pyplot as plt

# %%
import pandas
import numpy as np

# %% [markdown]
# แผนภูมิความร้อน heatmap สีในการแสดงค่า สีร้อนคือค่ามาก สีเย็นคือค่าน้อย

# %% [markdown]
# ## scatter plot กระจาย

# %%
irisdata = pandas.read_csv ('C:\\Users\\GTCOM\\Downloads\\iris.data',header=None)
irisdata
# Out:
#        0    1    2    3               4
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# plot แค่ต้นไม้ 1 ต้นก่อน คือ setosa

# %% [markdown]
# เอาแค่ 2 column จึงเป็น -3

# %%
setosa_np = irisdata.iloc[:50,:-1].to_numpy ()
setosa_np[:5,:]
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2]])

# %% [markdown]
# plot เฉพาะค่าที่จำเป็น

# %%
plt.scatter(setosa_np[:,0],setosa_np[:,1])

# %% [markdown]
# ตัวแรกหลัก x บอกแถว เราจะเอาทุกแถว หลักที่สองเป็นyเอาหลักที่ 0
# เอาทุกแถว เอาหลักที่1

# %% [markdown]
# s คือ scalar ตัวเลขหนึ่งตัวที่บอกแต่ขนาด
# The marker คือ จุด เครื่องหมายของมัน สามารถกำหนดขนาดของจุดด้วยพาามิเตอร์ตัว s

# %%
plt.scatter(setosa_np[:,0],setosa_np[:,1],s=60)

# %%
plt.scatter(setosa_np[:,0],setosa_np[:,1],s=setosa_np[:,2])

# %% [markdown]
# ขยายขนาดของจุด เพิ่มเลขข้างใน array คือคูณเข้าไป

# %%
plt.scatter(setosa_np[:,0],setosa_np[:,1],s=10*setosa_np[:,2])

# %% [markdown]
# c คือ color ค่าสีของจุดทั้งหมดของทุกตัว
# sequence หรือกำหนดสีตามตัวก็ได้
# แบบแรกใช้
# สีนอกจากจะแทนด้วยตัวหนังสือ ยังสามารถแทนด้วยตัวเลข

# %%
plt.scatter(setosa_np[:,0],setosa_np[:,1],s=10*setosa_np[:,2], c = "M")

# %%
setosa_np
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %%
print (f'max = {max(setosa_np[:,3])}, min = {min(setosa_np[:,3])}')
# Out:
# max = 0.6, min = 0.1

# %%
colors = []
for i in setosa_np[:,3] :
    if i < 0.15:
        colors.append('b')
    elif i < 0.3:
        colors.append('g')
    elif i < 0.45:
        colors.append('y')
    else:
        colors.append('r')
colors
# Out:
# ['g',
#  'g',
#  'g',
#  'g',
#  'g',
#  'y',
#  'y',
#  'g',
#  'g',
#  'b',
#  'g',
#  'g',
#  'b',
#  'b',
#  'g',
#  'y',
#  'y',
#  'y',
#  'y',
#  'y',
#  'g',
#  'y',
#  'g',
#  'r',
#  'g',
#  'g',
#  'y',
#  'g',
#  'g',
#  'g',
#  'g',
#  'y',
#  'b',
#  'g',
#  'b',
#  'g',
#  'g',
#  'b',
#  'g',
#  'g',
#  'y',
#  'y',
#  'g',
#  'r',
#  'y',
#  'y',
#  'g',
#  'g',
#  'g',
#  'g']

# %%
plt.scatter(setosa_np[:,0],setosa_np[:,1],s=30*setosa_np[:,2], c = colors)

# %%
plt.scatter(setosa_np[:,0],setosa_np[:,1],s=30*setosa_np[:,2], c = setosa_np[:,2])

# %% [markdown]
# ![alt text](https://matplotlib.org/_images/sphx_glr_colormaps_002.png)

# %%
plt.scatter(setosa_np[:,0],setosa_np[:,1],s=30*setosa_np[:,2], c = setosa_np[:,2], cmap = 'YlOrBr')

# %%
plt.scatter(setosa_np[:,0],setosa_np[:,1],s=30*setosa_np[:,2], c = np.array([[1,0.5,0.8]]))

# %% [markdown]
# The marker style กำหนดรูปแบบของจุด เช่น เป็นวงกลม สามเหลี่ยม สี่เหลี่ยม ทำได้หน้าตาทุกตัวเหมือนกัน

# %%
plt.scatter(setosa_np[:,0],setosa_np[:,1],s=30*setosa_np[:,2], c = setosa_np[:,2], cmap = 'YlOrBr',marker = 'X')

# %% [markdown]
# # Visualize 2 Data เพื่อดูว่า data 2 อันนี้ต่างหรือเหมือนกันอย่างไร

# %%
versicolor_np = irisdata.iloc[:50,:-1].to_numpy ()
versicolor_np
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %%
plt.scatter(setosa_np[:,0],setosa_np[:,1],s=30*setosa_np[:,2], c = setosa_np[:,3], cmap = 'BuPu',marker = 'P')
plt.scatter(versicolor_np[:,0],versicolor_np[:,1],s=30*versicolor_np[:,2], c = versicolor_np[:,3], cmap = 'BuPu',marker = '*')

# %% [markdown]
# # Visualize 3 Data

# %%
virginica_np = irisdata.iloc[100:,:-1].to_numpy ()
virginica_np
# Out:
# array([[6.3, 3.3, 6. , 2.5],
#        [5.8, 2.7, 5.1, 1.9],
#        [7.1, 3. , 5.9, 2.1],
#        [6.3, 2.9, 5.6, 1.8],
#        [6.5, 3. , 5.8, 2.2],
#        [7.6, 3. , 6.6, 2.1],
#        [4.9, 2.5, 4.5, 1.7],
#        [7.3, 2.9, 6.3, 1.8],
#        [6.7, 2.5, 5.8, 1.8],
#        [7.2, 3.6, 6.1, 2.5],
#        [6.5, 3.2, 5.1, 2. ],
#        [6.4, 2.7, 5.3, 1.9],
#        [6.8, 3. , 5.5, 2.1],
#        [5.7, 2.5, 5. , 2. ],
#        [5.8, 2.8, 5.1, 2.4],
#        [6.4, 3.2, 5.3, 2.3],
#        [6.5, 3. , 5.5, 1.8],
#        [7.7, 3.8, 6.7, 2.2],
#        [7.7, 2.6, 6.9, 2.3],
#        [6. , 2.2, 5. , 1.5],
#        [6.9, 3.2, 5.7, 2.3],
#        [5.6, 2.8, 4.9, 2. ],
#        [7.7, 2.8, 6.7, 2. ],
#        [6.3, 2.7, 4.9, 1.8],
#        [6.7, 3.3, 5.7, 2.1],
#        [7.2, 3.2, 6. , 1.8],
#        [6.2, 2.8, 4.8, 1.8],
#        [6.1, 3. , 4.9, 1.8],
#        [6.4, 2.8, 5.6, 2.1],
#        [7.2, 3. , 5.8, 1.6],
#        [7.4, 2.8, 6.1, 1.9],
#        [7.9, 3.8, 6.4, 2. ],
# ...

# %%
plt.scatter(setosa_np[:,0],setosa_np[:,1],s=30*setosa_np[:,2], c = setosa_np[:,3], cmap = 'BuPu',marker = 'P')
plt.scatter(versicolor_np[:,0],versicolor_np[:,1],s=30*versicolor_np[:,2], c = versicolor_np[:,3], cmap = 'BuPu',marker = '*')
plt.scatter(virginica_np[:,0],virginica_np[:,1],s=30*virginica_np[:,2], c = virginica_np[:,3], cmap = 'BuPu',marker = 'X')

# %% [markdown]
# # HW plot เทียบ 3 คลาสหลายๆแบบ

# %%
plt.scatter(setosa_np[:,3],setosa_np[:,2],s=30*setosa_np[:,1], c = setosa_np[:,0], cmap = 'Reds',marker = 'P')
plt.scatter(versicolor_np[:,0],versicolor_np[:,1],s=30*versicolor_np[:,2], c = versicolor_np[:,3], cmap = 'Reds',marker = '*')
plt.scatter(virginica_np[:,0],virginica_np[:,1],s=30*virginica_np[:,2], c = virginica_np[:,3], cmap = 'Reds',marker = 'X')

# %%
plt.scatter(setosa_np[:,3],setosa_np[:,2],s=30*setosa_np[:,1], c = setosa_np[:,0], cmap = 'Reds',marker = 'P')
plt.scatter(versicolor_np[:,3],versicolor_np[:,2],s=30*versicolor_np[:,1], c = versicolor_np[:,0], cmap = 'Reds',marker = '*')
plt.scatter(virginica_np[:,0],virginica_np[:,1],s=30*virginica_np[:,2], c = virginica_np[:,3], cmap = 'Reds',marker = 'X')

# %%
plt.scatter(setosa_np[:,3],setosa_np[:,2],s=30*setosa_np[:,1], c = setosa_np[:,0], cmap = 'Reds',marker = 'P')
plt.scatter(versicolor_np[:,3],versicolor_np[:,2],s=30*versicolor_np[:,1], c = versicolor_np[:,0], cmap = 'Reds',marker = '*')
plt.scatter(virginica_np[:,3],virginica_np[:,2],s=30*virginica_np[:,1], c = virginica_np[:,0], cmap = 'Reds',marker = 'X')

# %%
plt.scatter(setosa_np[:,3],setosa_np[:,2],s=30*setosa_np[:,1], c = setosa_np[:,0], cmap = 'Reds',marker = 'P')
plt.scatter(versicolor_np[:,2],versicolor_np[:,3],s=30*versicolor_np[:,0], c = versicolor_np[:,1], cmap = 'Reds',marker = '*')
plt.scatter(virginica_np[:,3],virginica_np[:,2],s=30*virginica_np[:,1], c = virginica_np[:,0], cmap = 'Reds',marker = 'X')

# %%
plt.scatter(setosa_np[:,3],setosa_np[:,2],s=30*setosa_np[:,1], c = setosa_np[:,0], cmap = 'Reds',marker = 'P')
plt.scatter(versicolor_np[:,0],versicolor_np[:,1],s=30*versicolor_np[:,2], c = versicolor_np[:,3], cmap = 'Reds',marker = '*')
plt.scatter(virginica_np[:,3],virginica_np[:,2],s=30*virginica_np[:,1], c = virginica_np[:,0], cmap = 'Reds',marker = 'X')

# %%
plt.scatter(setosa_np[:,3],setosa_np[:,2],s=30*setosa_np[:,1], c = setosa_np[:,0], cmap = 'Reds',marker = 'P')
plt.scatter(versicolor_np[:,0],versicolor_np[:,1],s=30*versicolor_np[:,3], c = versicolor_np[:,2], cmap = 'Reds',marker = '*')
plt.scatter(virginica_np[:,3],virginica_np[:,2],s=30*virginica_np[:,1], c = virginica_np[:,0], cmap = 'Reds',marker = 'X')

# %%
plt.scatter(setosa_np[:,3],setosa_np[:,2],s=30*setosa_np[:,1], c = setosa_np[:,0], cmap = 'Reds',marker = 'P')
plt.scatter(versicolor_np[:,2],versicolor_np[:,1],s=30*versicolor_np[:,3], c = versicolor_np[:,0], cmap = 'Reds',marker = '*')
plt.scatter(virginica_np[:,1],virginica_np[:,2],s=30*virginica_np[:,3], c = virginica_np[:,0], cmap = 'Reds',marker = 'X')

# %%
plt.scatter(setosa_np[:,3],setosa_np[:,2],s=30*setosa_np[:,1], c = setosa_np[:,0], cmap = 'Reds',marker = 'P')
plt.scatter(versicolor_np[:,2],versicolor_np[:,1],s=30*versicolor_np[:,3], c = versicolor_np[:,0], cmap = 'Reds',marker = '*')
plt.scatter(virginica_np[:,3],virginica_np[:,0],s=30*virginica_np[:,2], c = virginica_np[:,1], cmap = 'Reds',marker = 'X')

# %%
from matplotlib import pyplot  as plt
import matplotlib

# %%
matplotlib.rcParams['figure.figsize'] = [12,12]
plt.subplot (4,2,1)
plt.scatter(setosa_np[:,3],setosa_np[:,2],s=30*setosa_np[:,1], c = setosa_np[:,0], cmap = 'Reds',marker = 'P')
plt.scatter(versicolor_np[:,0],versicolor_np[:,1],s=30*versicolor_np[:,2], c = versicolor_np[:,3], cmap = 'Reds',marker = '*')
plt.scatter(virginica_np[:,0],virginica_np[:,1],s=30*virginica_np[:,2], c = virginica_np[:,3], cmap = 'Reds',marker = 'X')
plt.subplot (4,2,2)
plt.scatter(setosa_np[:,3],setosa_np[:,2],s=30*setosa_np[:,1], c = setosa_np[:,0], cmap = 'Reds',marker = 'P')
plt.scatter(versicolor_np[:,3],versicolor_np[:,2],s=30*versicolor_np[:,1], c = versicolor_np[:,0], cmap = 'Reds',marker = '*')
plt.scatter(virginica_np[:,0],virginica_np[:,1],s=30*virginica_np[:,2], c = virginica_np[:,3], cmap = 'Reds',marker = 'X')
plt.subplot (4,2,3)
plt.scatter(setosa_np[:,3],setosa_np[:,2],s=30*setosa_np[:,1], c = setosa_np[:,0], cmap = 'Reds',marker = 'P')
plt.scatter(versicolor_np[:,3],versicolor_np[:,2],s=30*versicolor_np[:,1], c = versicolor_np[:,0], cmap = 'Reds',marker = '*')
plt.scatter(virginica_np[:,3],virginica_np[:,2],s=30*virginica_np[:,1], c = virginica_np[:,0], cmap = 'Reds',marker = 'X')
plt.subplot (4,2,4)
plt.scatter(setosa_np[:,3],setosa_np[:,2],s=30*setosa_np[:,1], c = setosa_np[:,0], cmap = 'Reds',marker = 'P')
plt.scatter(versicolor_np[:,2],versicolor_np[:,3],s=30*versicolor_np[:,0], c = versicolor_np[:,1], cmap = 'Reds',marker = '*')
plt.scatter(virginica_np[:,3],virginica_np[:,2],s=30*virginica_np[:,1], c = virginica_np[:,0], cmap = 'Reds',marker = 'X')
plt.subplot (4,2,5)
plt.scatter(setosa_np[:,3],setosa_np[:,2],s=30*setosa_np[:,1], c = setosa_np[:,0], cmap = 'Reds',marker = 'P')
plt.scatter(versicolor_np[:,0],versicolor_np[:,1],s=30*versicolor_np[:,2], c = versicolor_np[:,3], cmap = 'Reds',marker = '*')
plt.scatter(virginica_np[:,3],virginica_np[:,2],s=30*virginica_np[:,1], c = virginica_np[:,0], cmap = 'Reds',marker = 'X')
plt.subplot (4,2,6)
plt.scatter(setosa_np[:,3],setosa_np[:,2],s=30*setosa_np[:,1], c = setosa_np[:,0], cmap = 'Reds',marker = 'P')
plt.scatter(versicolor_np[:,0],versicolor_np[:,1],s=30*versicolor_np[:,3], c = versicolor_np[:,2], cmap = 'Reds',marker = '*')
plt.scatter(virginica_np[:,3],virginica_np[:,2],s=30*virginica_np[:,1], c = virginica_np[:,0], cmap = 'Reds',marker = 'X')
plt.subplot (4,2,7)
plt.scatter(setosa_np[:,3],setosa_np[:,2],s=30*setosa_np[:,1], c = setosa_np[:,0], cmap = 'Reds',marker = 'P')
plt.scatter(versicolor_np[:,2],versicolor_np[:,1],s=30*versicolor_np[:,3], c = versicolor_np[:,0], cmap = 'Reds',marker = '*')
plt.scatter(virginica_np[:,1],virginica_np[:,2],s=30*virginica_np[:,3], c = virginica_np[:,0], cmap = 'Reds',marker = 'X')
plt.subplot (4,2,8)
plt.scatter(setosa_np[:,3],setosa_np[:,2],s=30*setosa_np[:,1], c = setosa_np[:,0], cmap = 'Reds',marker = 'P')
plt.scatter(versicolor_np[:,2],versicolor_np[:,1],s=30*versicolor_np[:,3], c = versicolor_np[:,0], cmap = 'Reds',marker = '*')
plt.scatter(virginica_np[:,3],virginica_np[:,0],s=30*virginica_np[:,2], c = virginica_np[:,1], cmap = 'Reds',marker = 'X')
plt.show ()
